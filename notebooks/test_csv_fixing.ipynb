# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\user\Desktop\ML & DL projects\Anti- Money Laundering classification\data\raw\LI-Small_Trans.csv')
df.columns = df.columns.str.replace(' ', '_').str.replace('.', '_').str.lower()
df.head(5)
# Out:
#           timestamp  from_bank    account  to_bank  account_1  \
# 0  2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1  2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2  2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3  2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4  2022/09/01 00:00         20  8006AD530       20  8006AD530
#
#    amount_received receiving_currency  amount_paid payment_currency  \
# 0       3195403.00          US Dollar   3195403.00        US Dollar
# 1          1858.96          US Dollar      1858.96        US Dollar
# 2        592571.00          US Dollar    592571.00        US Dollar
# 3            12.32          US Dollar        12.32        US Dollar
# 4          2941.56          US Dollar      2941.56        US Dollar
#
#   payment_format  is_laundering
# 0   Reinvestment              0
# 1   Reinvestment              0
# 2         Cheque              0
# 3   Reinvestment              0
# ...

# %%
print(df.columns.tolist())
# Out:
# ['timestamp', 'from_bank', 'account', 'to_bank', 'account_1', 'amount_received', 'receiving_currency', 'amount_paid', 'payment_currency', 'payment_format', 'is_laundering']

# %%
df1 = df.copy()

df1.drop(columns='is_laundering', axis=1, inplace=True)

df1.head(5)
# Out:
#           timestamp  from_bank    account  to_bank  account_1  \
# 0  2022/09/01 00:08         11  8000ECA90       11  8000ECA90
# 1  2022/09/01 00:21       3402  80021DAD0     3402  80021DAD0
# 2  2022/09/01 00:00         11  8000ECA90     1120  8006AA910
# 3  2022/09/01 00:16       3814  8006AD080     3814  8006AD080
# 4  2022/09/01 00:00         20  8006AD530       20  8006AD530
#
#    amount_received receiving_currency  amount_paid payment_currency  \
# 0       3195403.00          US Dollar   3195403.00        US Dollar
# 1          1858.96          US Dollar      1858.96        US Dollar
# 2        592571.00          US Dollar    592571.00        US Dollar
# 3            12.32          US Dollar        12.32        US Dollar
# 4          2941.56          US Dollar      2941.56        US Dollar
#
#   payment_format
# 0   Reinvestment
# 1   Reinvestment
# 2         Cheque
# 3   Reinvestment
# 4   Reinvestment

# %%
df1.to_csv(r"C:\Users\user\Desktop\ML & DL projects\Anti- Money Laundering classification\data\processed\test.csv", index=False)
